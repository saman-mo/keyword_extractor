# %%
import json

import sys
sys.path.insert(0,'..')

from ai_es_utils.queries.composers import DecayLastScrapedGroupedComposer, GroupByNameComposer
from ai_es_utils.queries.components import *
from ai_es_utils.queries.models.payload import RequestPayload, Query

from ai_es_utils.services.search.geolocation_service import GeoLocationService, ElasticSearchService
from ai_es_utils.services.enrichment.job2jobs_client import Job2JobsService
from ai_es_utils.services.enrichment.job2skills_client import Job2SkillsService
from ai_es_utils.search.search_executor import SearchExecutor

from ai_es_utils.queries.builder.query_expander import BANKING_JOB2JOBS
from ai_es_utils.queries.builder.queries import MATCH_EXECUTIVE_QUERY
from ai_es_utils.queries.builder.country_names import COUNTRY_NAMES

# %% [markdown]
# Build search by selecting search components to use:

# %%
gender_map = json.load(open("../data/map_to_gender_specific_job_titles.json"))
country_names = json.load(open("../data/country_names_map.json"))
executive_query = json.load(open("../data/match_executive_query.json"))

curated_skills = json.load(open("../data/curated_skills_expansion.json"))
curated_jobs = json.load(open("../data/curated_jobs_expansion.json"))

coordinates_service = ElasticSearchService("es-dev.internal.talentwunder.com" , 80, "coordinates")
geolocation_service = GeoLocationService(coordinates_service)

job2jobs_service = Job2JobsService("https://api-dev.talentwunder.com", topn=20)
job2skills_service = Job2SkillsService("https://api-dev.talentwunder.com", topn=20)

# %%
query_stack = [
    # Filter queries:
    IncludePortalsQuery(),
    GenderQuery(),
    IsStudentQuery(),
    IsFreelancerQuery(),
    IsRecruiterQuery(),
    IsConsultantQuery(),
    IsEntrepreneurQuery(),
    IsScientistQuery(),
    LanguagesQuery(),
    MonthsWorkingQuery(),
    MinMobilityQuery(),
    MinChangeProbabilityQuery(),
    HasPhoneQuery(),
    HasEmailQuery(),
    DistanceQuery(geolocation_service=geolocation_service),
    CountryQuery(country_names=country_names),
    # Most not:
    HideInSearchQuery(),
    ExecutiveOnlyQuery(curated_executive_sub_query=executive_query),
    ExcludePortalsQuery(),
    #Should:
    LocationQuery(),
    #Must
    IndustryCodeQuery(),
    SkillQuery(),
    FunctionScoreQuery(),
    JobTitleQuery(gender_map, name="job_title_expansion"),
    JobTitleExpansionQuery(job2jobs_service=job2jobs_service, gender_normalization_map=gender_map, curated_jobs_expansion=curated_jobs, name="job_title_expansion"), # Arguments
    SkillExpansionQuery(job2skills_service=job2skills_service, gender_normalization_map=gender_map, curated_skills_expansion=curated_skills, name="job_title_expansion"), # Arguments
    MinimumShouldMatchQuery(name="job_title_expansion", bool_key="must"),
    WorksAtQuery(),
    WorksNotAtQuery(),
    WorksAtPreviouslyQuery(),
    WorksNotAtPreviouslyQuery(),
    #Other
    SortQuery(),
    SizeAndOffsetQuery(),
    HighlightQuery()
]

query_composer = DecayLastScrapedGroupedComposer()

# %%
bearer_token="Bearer: eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJlUFU3aDNWTnlPaG1NZjl6LVNIbmduZTh5cUFRVzZSZUhyZ3ZRUVo5R20wIn0.....UItjCX8CcOdTIvIv1GLeJVBJ4_jP9gYaT1YO77pxkh1KgNidugsXVhjHP1CHX0EoIboZnR_KDOFmjMcUcVpb1uoawnn0Ye8CCQBEuK5dyAp46FDTDhXeaRfzkC4maNYdJekYhMdjBsnfSbV4OkbFZbfWOhnwO4KUYIdRI-Wf26FhCCdn1PwK76HSzpbnhAJNUNbScpbAMHX50BXNz1GevLkCHkrdreVZ2IvzZUaj10RA64iItsYDfl2JRLYd8ZpQnLOmCaVSH1F7JfAHeaIH0d8Dg2h3Ip6dwoy6v1pN6vx5Ps9rv8LX1kr7WFtkWAABnzvFyhHp-UAw3-8BpXeBvw"
request = RequestPayload(
            query=Query(
                jobTitle="developer",
                skills=["java"],
                isMale=True
            )
        )

# %%
test_source = json.load(open("test_full_payload.json"))
request = RequestPayload(**test_source["payload"])
query_list = []
for c in query_stack:
    query_list.append(c.query(request, bearer_token=bearer_token).query)
query = query_composer(query_list, timeout="59s", track_scores=True)
query
# Out:
# {'query': {'function_score': {'functions': [{'gauss': {'lastScraped': {'decay': 0.3,
#        'offset': '30d',
#        'origin': 'now',
#        'scale': '90d'}}}],
#    'query': {'bool': {'filter': [{'terms': {'_class': ['bintray', 'techgig']}},
#       {'term': {'gender': 'm'}},
#       {'term': {'isStudent': True}},
#       {'term': {'isFreelancer': True}},
#       {'term': {'isRecruiter': True}},
#       {'term': {'isConsultant': True}},
#       {'term': {'isEntrepreneur': True}},
#       {'term': {'isScientist': True}},
#       {'bool': {'should': [{'query_string': {'query': 'spanish AND deutsch',
#            'fields': ['languagesString^1.0'],
#            'default_operator': 'or',
#            'type': 'best_fields'}}]}},
#       {'range': {'monthsWorking': {'include_lower': True,
#          'include_upper': True,
#          'from': 12,
#          'to': 48}}},
#       {'range': {'mobility': {'gte': 55}}},
#       {'range': {'changeProbability': {'gte': 89}}},
#       {'term': {'hasPhone': True}},
#       {'term': {'hasEmail': True}},
#       {'geo_distance': {'distance': 50000,
#         'distance_type': 'arc',
#         'geoPoint': [10.13489, 54.32133]}},
#       {'bool': {'should': [{'query_string': {'query': 'DE OR de',
#            'fields': ['address.countryCode^1.0'],
#            'type': 'best_fields',
#            'default_operator': 'or'}},
#          {'query_string': {'query': ' "Deutschland"  OR  "Allemagne"  OR  "Alemania"  OR  "Germany" ',
#            'fields': ['location^1.0'],
#            'type': 'best_fields',
#            'default_operator': 'or'}}],
#         '_name': 'country'}}],
#      'must_not': [{'match': {'_hideInSearch': True}}],
#      'must': [{'nested': {'path': 'jobs',
#         'query': {'bool': {'must': [{'term': {'jobs.industryCode': '001'}}]}}}},
#       {'bool': {'should': [{'match_phrase': {'skills': 'j2ee'}},
#          {'match_phrase': {'jobTitle': 'j2ee'}},
#          {'match_phrase': {'previousJobTitles': 'j2ee'}},
#          {'match_phrase': {'industry': 'j2ee'}},
#          {'match_phrase': {'study': 'j2ee'}}],
#         'minimum_should_match': 1}},
#       {'function_score': {'boost': 1.0,
#         'functions': [{'field_value_factor': {'factor': 1,
#            'field': 'ml5.profileQuality',
#            'missing': 4,
#            'modifier': 'sqrt'}}],
#         'max_boost': 3.4028235e+38,
#         'query': {'match_all': {'boost': 1}},
#         'score_mode': 'multiply'}},
#       {'bool': {'should': [{'nested': {'path': 'jobs',
#            'query': {'query_string': {'fields': ['jobs.jobTitle'],
#              'query': 'Vertriebsleit* OR Niederlassungsleit* OR Hausleit* OR "Head of" OR VP OR teamlead OR "team lead" OR lead OR director OR Direktor OR Regionaldirektor OR Salesdirektor OR CEO OR "Chief Executive Officer" OR COO OR "Chief Operating Officer" OR CPO OR Chief OR "Chief Product Officer" OR CTO OR "Chief Technology Officer" OR CFO OR "Chief Financial Officer" OR CMO OR "Chief Marketing Officer" OR CSO OR "Chief Sales Officer" OR "Chief Security Officer" OR CHRO OR "Chief Human Resources Officer" OR CDO OR "Chief Data Officer" OR CRO OR "Chief Revenue Officer" OR "executive officer" OR chairman OR "member of board" OR "member of the board" OR "board member" OR "executive partner" OR "member of the board of directors" OR Geschäftsführer* OR "geschäftsführender Teilhaber" OR Leit* OR Bereichsleit* OR Teamleit* OR Abteilungsleit* OR Filialleit* OR Schichtleit* OR Personalleit* OR Personalchef* OR "group head" OR Prokurist OR president OR "managing director" OR "managing partner" OR Vorstandsvorsitzender OR "vorsitzender des vorstandes" OR Vorstandsmitglied OR "mitglied im vorstand" OR "Vorstand für" OR "Vorständin für" OR "geschäftsführender vorstand" OR hauptgeschäftsführer OR aufsichtsratsvorsitzender OR "vorsitzender des aufsichtsrats" OR "geschäftsführender partner" OR Finanzvorstand OR Personalvorstand OR "Chef vom Dienst" OR Redaktionsleit* OR Restaurantleit* OR Küchenchef* OR Chefkoch OR Chefköchin OR Rezeptionsleit* OR Bauleit* OR Oberarzt OR Führungsposition OR verkaufsleiter '}}}},
#          {'query_string': {'fields': ['jobTitle', 'previousJobTitles'],
#            'query': 'Vertriebsleit* OR Niederlassungsleit* OR Hausleit* OR "Head of" OR VP OR teamlead OR "team lead" OR lead OR director OR Direktor OR Regionaldirektor OR Salesdirektor OR CEO OR "Chief Executive Officer" OR COO OR "Chief Operating Officer" OR CPO OR Chief OR "Chief Product Officer" OR CTO OR "Chief Technology Officer" OR CFO OR "Chief Financial Officer" OR CMO OR "Chief Marketing Officer" OR CSO OR "Chief Sales Officer" OR "Chief Security Officer" OR CHRO OR "Chief Human Resources Officer" OR CDO OR "Chief Data Officer" OR CRO OR "Chief Revenue Officer" OR "executive officer" OR chairman OR "member of board" OR "member of the board" OR "board member" OR "executive partner" OR "member of the board of directors" OR Geschäftsführer* OR "geschäftsführender Teilhaber" OR Leit* OR Bereichsleit* OR Teamleit* OR Abteilungsleit* OR Filialleit* OR Schichtleit* OR Personalleit* OR Personalchef* OR "group head" OR Prokurist OR president OR "managing director" OR "managing partner" OR Vorstandsvorsitzender OR "vorsitzender des vorstandes" OR Vorstandsmitglied OR "mitglied im vorstand" OR "Vorstand für" OR "Vorständin für" OR "geschäftsführender vorstand" OR hauptgeschäftsführer OR aufsichtsratsvorsitzender OR "vorsitzender des aufsichtsrats" OR "geschäftsführender partner" OR Finanzvorstand OR Personalvorstand OR "Chef vom Dienst" OR Redaktionsleit* OR Restaurantleit* OR Küchenchef* OR Chefkoch OR Chefköchin OR Rezeptionsleit* OR Bauleit* OR Oberarzt OR Führungsposition OR verkaufsleiter ',
#            'type': 'best_fields',
#            'default_operator': 'or'}}],
#         '_name': 'executive_only',
#         'minimum_should_match': 1}},
#       {'bool': {'should': [{'match_phrase': {'jobTitle': 'java developer'}},
#          {'match_phrase': {'previousJobTitles': 'java developer'}},
#          {'match_phrase': {'jobTitle': 'senior java developer'}},
#          {'match_phrase': {'previousJobTitles': 'senior java developer'}},
#          {'match_phrase': {'jobTitle': 'senior java engineer'}},
#          {'match_phrase': {'previousJobTitles': 'senior java engineer'}},
#          {'match_phrase': {'jobTitle': 'scala developer'}},
#          {'match_phrase': {'previousJobTitles': 'scala developer'}},
#          {'match_phrase': {'jobTitle': 'junior java developer'}},
#          {'match_phrase': {'previousJobTitles': 'junior java developer'}},
#          {'match_phrase': {'jobTitle': 'java team leader'}},
#          {'match_phrase': {'previousJobTitles': 'java team leader'}},
#          {'match_phrase': {'jobTitle': 'freelance java developer'}},
#          {'match_phrase': {'previousJobTitles': 'freelance java developer'}},
#          {'match_phrase': {'jobTitle': 'j2ee developer'}},
#          {'match_phrase': {'previousJobTitles': 'j2ee developer'}},
#          {'match_phrase': {'jobTitle': 'senior j2ee consultant'}},
#          {'match_phrase': {'previousJobTitles': 'senior j2ee consultant'}},
#          {'match_phrase': {'jobTitle': 'java software developer'}},
#          {'match_phrase': {'previousJobTitles': 'java software developer'}},
#          {'match_phrase': {'jobTitle': 'java architect'}},
#          {'match_phrase': {'previousJobTitles': 'java architect'}},
#          {'match_phrase': {'jobTitle': 'java analyst developer'}},
#          {'match_phrase': {'previousJobTitles': 'java analyst developer'}},
#          {'match_phrase': {'jobTitle': 'middleware developer'}},
#          {'match_phrase': {'previousJobTitles': 'middleware developer'}},
#          {'match_phrase': {'jobTitle': 'java j2ee developer'}},
#          {'match_phrase': {'previousJobTitles': 'java j2ee developer'}},
#          {'match_phrase': {'jobTitle': 'java full stack developer'}},
#          {'match_phrase': {'previousJobTitles': 'java full stack developer'}},
#          {'match_phrase': {'jobTitle': 'java analyst programmer'}},
#          {'match_phrase': {'previousJobTitles': 'java analyst programmer'}},
#          {'match_phrase': {'jobTitle': 'java tech lead'}},
#          {'match_phrase': {'previousJobTitles': 'java tech lead'}},
#          {'match_phrase': {'jobTitle': 'java developer contract'}},
#          {'match_phrase': {'previousJobTitles': 'java developer contract'}},
#          {'match_phrase': {'jobTitle': 'java consultant'}},
#          {'match_phrase': {'previousJobTitles': 'java consultant'}},
#          {'match_phrase': {'jobTitle': 'java instructor'}},
#          {'match_phrase': {'previousJobTitles': 'java instructor'}},
#          {'query_string': {'query': ' "assertj"  OR  "enterprise edition"  OR  "hibernate-framework"  OR  "servlets"  OR  "spring framework"  OR  "hibernate"  OR  "spring"  OR  "apache maven"  OR  "richfaces"  OR  "intellij idea"  OR  "jee"  OR  "jsf2"  OR  "maven"  OR  "junit"  OR  "jpa"  OR  "jsf"  OR  "java//j2ee"  OR  "core java"  OR  "servlet"  OR  "spring mvc" ',
#            'fields': ['skills'],
#            'type': 'best_fields',
#            'default_operator': 'or',
#            'minimum_should_match': 4}}],
#         '_name': 'job_title_expansion',
#         'minimum_should_match': 1}},
#       {'bool': {'should': [{'query_string': {'query': 'google',
#            'fields': ['company^1.0'],
#            'type': 'best_fields',
#            'default_operator': 'or'}}],
#         '_name': 'works_at',
#         'minimum_should_match': 1}},
#       {'bool': {'should': [{'query_string': {'query': 'NOT (google)',
#            'fields': ['previousCompanies^1.0'],
#            'type': 'best_fields',
#            'default_operator': 'or'}},
#          {'query_string': {'query': 'NOT (google)',
#            'fields': ['previousCompanies^1.0'],
#            'type': 'best_fields',
#            'default_operator': 'or'}}],
#         '_name': 'works_not_at_previously',
#         'minimum_should_match': 1}}],
#      'should': [{'match': {'location': 'Kiel'}}]}}}},
#  'sort': [{'_score': {'order': 'desc'}}],
#  'from': 0,
#  'size': 30,
#  'highlight': {'fields': {'company': {},
#    'email': {},
#    'jobTitle': {},
#    'jobs.jobTitle': {},
#    'jobs.notes': {},
#    'location': {},
#    'previousCompanies': {},
#    'previousJobTitles': {},
#    'skills': {}},
#   'post_tags': '</mark>',
#   'pre_tags': '<mark>',
#   'require_field_match': False},
#  'timeout': '59s',
#  'track_scores': True}

# %% [markdown]
# For comparison we need to remove the additional name field that we introduced to group the queries.

# %%
from deepdiff import DeepDiff
print(DeepDiff(query, test_source["autoquery"], ignore_order=True))
# Out:
# {'dictionary_item_removed': [root['query']['function_score']['query']['bool']['must'][3]['bool']['_name'], root['query']['function_score']['query']['bool']['must'][4]['bool']['_name'], root['query']['function_score']['query']['bool']['must'][5]['bool']['_name'], root['query']['function_score']['query']['bool']['must'][6]['bool']['_name'], root['query']['function_score']['query']['bool']['filter'][15]['bool']['_name']]}

# %% [markdown]
# We can safely ignore the missing "name" items, since they are added by the new implementation to get the grouping to work.

# %%
json.dump(query, open("test.json", "w"), indent=2)

# %% [markdown]
# # Putting everything together

# %%
smart_search = SearchExecutor(
    ElasticSearchService("es-dev.internal.talentwunder.com" , 80, "prod"),
    query_stack=query_stack,
    query_composer=query_composer
)

# %%
smart_search(request, bearer_token=bearer_token, history_id="asdf")
# Out:
# {'profileInstanceList': [],
#  'profileInstanceCount': 0,
#  'location': GeoPoint(lat=54.32133, long=10.13489),
#  'semanticExpansion': {'jobs': [{'name': 'senior java developer',
#     'isChecked': True},
#    {'name': 'senior java engineer', 'isChecked': True},
#    {'name': 'scala developer', 'isChecked': True},
#    {'name': 'junior java developer', 'isChecked': True},
#    {'name': 'java team leader', 'isChecked': True},
#    {'name': 'freelance java developer', 'isChecked': True},
#    {'name': 'j2ee developer', 'isChecked': True},
#    {'name': 'senior j2ee consultant', 'isChecked': True},
#    {'name': 'java software developer', 'isChecked': True},
#    {'name': 'java architect', 'isChecked': True},
#    {'name': 'java analyst developer', 'isChecked': True},
#    {'name': 'middleware developer', 'isChecked': True},
#    {'name': 'java j2ee developer', 'isChecked': True},
#    {'name': 'java full stack developer', 'isChecked': True},
#    {'name': 'java analyst programmer', 'isChecked': True},
#    {'name': 'java tech lead', 'isChecked': True},
#    {'name': 'java developer contract', 'isChecked': True},
#    {'name': 'java consultant', 'isChecked': True},
#    {'name': 'java instructor', 'isChecked': True}],
#   'skills': [{'name': 'assertj', 'isChecked': True},
#    {'name': 'enterprise edition', 'isChecked': True},
#    {'name': 'hibernate-framework', 'isChecked': True},
#    {'name': 'servlets', 'isChecked': True},
#    {'name': 'spring framework', 'isChecked': True},
#    {'name': 'hibernate', 'isChecked': True},
#    {'name': 'spring', 'isChecked': True},
#    {'name': 'apache maven', 'isChecked': True},
#    {'name': 'richfaces', 'isChecked': True},
#    {'name': 'intellij idea', 'isChecked': True},
#    {'name': 'jee', 'isChecked': True},
#    {'name': 'jsf2', 'isChecked': True},
#    {'name': 'maven', 'isChecked': True},
#    {'name': 'junit', 'isChecked': True},
#    {'name': 'jpa', 'isChecked': True},
#    {'name': 'jsf', 'isChecked': True},
#    {'name': 'java/j2ee', 'isChecked': True},
#    {'name': 'core java', 'isChecked': True},
#    {'name': 'servlet', 'isChecked': True},
#    {'name': 'spring mvc', 'isChecked': True}]},
#  'history_id': 'asdf'}

# %%
request = RequestPayload(
            query=Query(
                jobTitle="Software Developer",
                location="Berlin",
                isMale=True,
                distance=50
            )
        )

smart_search(request, bearer_token=bearer_token, history_id="asdf")
# Out:
# {'profileInstanceList': [{'_class': 'xing',
#    'profileURL': 'https://www.xing.com/profile/Reza_Toorani',
#    'uid': '5f18de83d7951f0caa556683',
#    'handle': 'reza_toorani',
#    'imageURL': 'https://profile-images.xing.com/images/9726cbd26fa369c2f1cfadc3fa01444c-9/reza-toorani.256x256.jpg',
#    'fullName': 'Reza Toorani',
#    'name': 'Reza Toorani',
#    'firstName': 'Reza',
#    'lastName': 'Toorani',
#    'geoPoint': {'lat': 52.52000659999999, 'lon': 13.404954},
#    'address': {'countryCode': 'de',
#     'country': 'Deutschland',
#     'state': '6.0',
#     'city': 'Berlin'},
#    'location': '<mark>Berlin</mark>, Germany',
#    'jobTitle': 'Senior <mark>Backend</mark> <mark>Developer</mark>',
#    'previousJobTitles': ['<mark>Senior</mark> <mark>Software</mark> <mark>Developer</mark>',
#     'Full Stack <mark>Developer</mark>',
#     'Mid VB.NET <mark>Developer</mark>',
#     'Junior VB.NET <mark>Developer</mark>'],
#    'industry': 'Employee, Senior Backend Developer, Sablono GmbH',
#    'company': 'Sablono GmbH',
#    'previousCompanies': ['GLIWA GmbH embedded systems',
#     'Saman Salamat Pajoh',
#     'TOSAN Smart Information Systems (SOHA)',
#     'Yaas Arghavani Industrial Engineering',
#     'Arian System Co',
#     'Mahkar Caspian',
#     'Sepehr Co'],
#    'skills': ['<mark>C#.NET</mark>',
#     'Microsoft Visual Studio',
#     'JavaScript',
#     'Object Oriented Programming',
#     'Design pattern',
#     'ASP.NET',
#     'MVC',
#     'Microsoft SQL Server',
#     'ADO',
#     'ADO.NET',
#     'jQuery',
#     'N-Tier Architectur',
#     'AngularJS',
#     '.Net',
#     '.Net Core',
#     '<mark>Entity</mark> <mark>Framwork</mark>',
#     'CSS',
#     'Vue.js',
#     'T-SQL',
#     'C#',
#     '<mark>C#</mark> <mark>Development</mark>',
#     'C# Programmierung',
#     'C#-Entwicklung',
#     'DevOps',
#     '<mark>.NET</mark> <mark>Framework</mark>',
#     'SQL',
#     'SQL Server',
#     'NoSQL',
#     'Lösung',
#     'WPF',
#     'Agile Development',
#     'Unit Testing',
#     'TypeScript',
#     'Docker',
#     '<mark>Object</mark> <mark>Oriented</mark> <mark>Programming</mark> (<mark>OOP</mark>)',
#     'Angular',
#     'Git',
#     'HTML'],
#    'languagesString': 'English en German de Persian fa',
#    'languages': [{'name': 'English',
#      'level': 'Fluent',
#      'code': 'en',
#      'levelCode': 4},
#     {'name': 'German', 'level': 'Basic', 'code': 'de', 'levelCode': 2},
#     {'name': 'Persian', 'level': '-', 'code': 'fa'}],
#    'jobs': [{'jobTitle': 'Senior <mark>Backend</mark> <mark>Developer</mark>',
#      'periodStart': '2020-12-01T00:00:00.000Z',
#      'company': 'Sablono GmbH'},
#     {'jobTitle': '<mark>Senior</mark> <mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2020-09-01T00:00:00.000Z',
#      'periodEnd': '2020-11-30T23:59:59.000Z',
#      'company': 'GLIWA GmbH embedded systems',
#      'industryCode': '006',
#      'notes': 'Development of a desktop application in C# and .Net 4.7.2 in the domain of timing analysis for embedded software Extension and improvement of a Swagger based <mark>REST</mark> <mark>API</mark> Extension and maintenance of system tests'},
#     {'jobTitle': 'Full Stack <mark>Developer</mark>',
#      'periodStart': '2012-09-01T00:00:00.000Z',
#      'periodEnd': '2020-02-29T23:59:59.000Z',
#      'company': 'Saman Salamat Pajoh',
#      'notes': '• Enhanced user satisfaction and diminished maintenance costs by using test-driven and agile principles in track and trace project with more than 500K users • Participated in boosting the productivity of development, support, marketing, and network teams by using DevOps concepts such as CI/CD, monitoring, and room support in the teams. • Transferring experiences and skills in software development special in track and trace health product to more than 20 programmers over seven years'},
#     {'jobTitle': 'Full Stack <mark>Developer</mark>',
#      'periodStart': '2011-02-01T00:00:00.000Z',
#      'periodEnd': '2012-08-31T23:59:59.000Z',
#      'company': 'TOSAN Smart Information Systems (SOHA)',
#      'notes': '• Diminished E-ticket credit problems by designing and implementing an E-ticket credit management application'},
#     {'jobTitle': 'Mid VB.NET <mark>Developer</mark>',
#      'periodStart': '2009-05-01T00:00:00.000Z',
#      'periodEnd': '2011-01-31T23:59:59.000Z',
#      'company': 'Yaas Arghavani Industrial Engineering',
#      'notes': '• Reduced development time and bettered writing clean code by using design patterns and object-oriented principles for banking applications'},
#     {'jobTitle': 'Mid VB.NET <mark>Developer</mark>',
#      'periodStart': '2007-09-01T00:00:00.000Z',
#      'periodEnd': '2009-03-31T23:59:59.000Z',
#      'company': 'Arian System Co',
#      'notes': '• Increased technical feasibility solutions for new functions in ERP by designing and implementing a framework using Factory, Proxy, ORM, Singleton, Command, and IOC patterns'},
#     {'jobTitle': 'Junior VB.NET Developer',
#      'periodStart': '2006-07-01T00:00:00.000Z',
#      'periodEnd': '2007-07-31T23:59:59.000Z',
#      'company': 'Mahkar Caspian',
#      'notes': '• Raised 100% performance salary calculation of 8K employees of Maskan Bank through stored procedures, DB functions, and business layer modules after migration old data from a mainframe computer to the Oracle database.'},
#     {'jobTitle': 'Junior VB.NET Developer',
#      'periodStart': '2005-07-01T00:00:00.000Z',
#      'periodEnd': '2006-06-30T23:59:59.000Z',
#      'company': 'Sepehr Co',
#      'industryCode': '009',
#      'notes': '• Decreased developing and supporting costs of e-Learn Management System (LMS) by customizing Rainbow (CMS ASP.NET open source)'}],
#    'education': [{'school': 'Azad University',
#      'study': 'Software Engineering'}],
#    'gender': 'm',
#    'hasEmail': False,
#    'hasPhone': False,
#    'hasFax': False,
#    'changeProbability': 35,
#    'mobility': 20,
#    'monthsInJob': 10,
#    'monthsWorking': 188,
#    '_hideInSearch': False,
#    'lastScraped': '2021-10-14T23:49:11.038Z',
#    'lastUpdated': '2021-10-16T06:08:02.732Z',
#    'isFreelancer': False,
#    'isConsultant': False,
#    'isRecruiter': False,
#    'isEntrepreneur': False,
#    'isStudent': False,
#    'isScientist': False,
#    'ml5': {'similarProfiles': {'encoding': ['pos0cluster22',
#       'pos1cluster7',
#       'pos2cluster22',
#       'pos3cluster13',
#       'pos4cluster30',
#       'pos5cluster1',
#       'pos6cluster4',
#       'pos7cluster23',
#       'pos8cluster4',
#       'pos9cluster7',
#       'pos10cluster12',
#       'pos11cluster10',
#       'pos12cluster12',
#       'pos13cluster1',
#       'pos14cluster16',
#       'pos15cluster20',
#       'pos16cluster12',
#       'pos17cluster6',
#       'pos18cluster1',
#       'pos19cluster7']},
#     'profileQuality': 7},
#    '_id': 'aHR0cHM6Ly93d3cueGluZy5jb20vcHJvZmlsZS9SZXphX1Rvb3Jhbmk',
#    'relevance': 100},
#   {'_class': 'xing',
#    'profileURL': 'https://www.xing.com/profile/Imants_Parsjukevics',
#    'uid': '5b3ba27446e0fb0012ef836e',
#    'handle': 'imants_parsjukevics',
#    'imageURL': 'https://profile-images.xing.com/images/ca96725002f2eb01086e272955318ee2-1/imants-parsjukevics.256x256.jpg',
#    'fullName': 'Imants Parsjukevics',
#    'name': 'Imants Parsjukevics',
#    'firstName': 'Imants',
#    'lastName': 'Parsjukevics',
#    'geoPoint': {'lat': 52.52000659999999, 'lon': 13.404954},
#    'address': {'countryCode': 'de',
#     'country': 'Deutschland',
#     'state': '6.0',
#     'city': 'Berlin'},
#    'location': '<mark>Berlin</mark>, Germany',
#    'jobTitle': '<mark>Software</mark> <mark>Engineer</mark>',
#    'previousJobTitles': ['<mark>Senior</mark> <mark>Software</mark> <mark>Engineer</mark>',
#     '.NET <mark>Software</mark> <mark>Developer</mark>'],
#    'industry': 'Employee, Software Engineer, KARL STORZ SE & Co. KG',
#    'company': 'KARL STORZ SE & Co. KG',
#    'previousCompanies': ['COMPLEVO GmbH',
#     'Mitto AG',
#     'EffectiveSoft',
#     'Itransition',
#     'CodingStaff'],
#    'skills': ['C#',
#     '<mark>.NET</mark> <mark>Framework</mark>',
#     'OOP',
#     'Design Patterns',
#     'MVC',
#     'ASP.NET',
#     'ASP.NET WebAPI',
#     'Windows Azure',
#     'Amazon Web Services(AWS)',
#     'WCF',
#     '<mark>WPF</mark>',
#     'Windows Forms',
#     'MsSQL',
#     '<mark>Entity</mark> <mark>Framwork</mark>',
#     'JavaScript',
#     '<mark>Angular</mark>',
#     '<mark>Angular</mark>JS',
#     'KnockoutJS',
#     'Twitter Bootstrap',
#     'jQuery',
#     'HTML',
#     'CSS',
#     'XML',
#     'Python',
#     'Microsoft Visual Studio',
#     'LINQ',
#     '.net core',
#     '<mark>asp.net</mark> <mark>core</mark>',
#     'Typescript',
#     'Kendo',
#     'Git',
#     'Softwareentwicklung',
#     'Docker',
#     'SQL',
#     'Scrum'],
#    'languagesString': 'English en Russian ru German de',
#    'languages': [{'name': 'English',
#      'level': 'Intermediate',
#      'code': 'en',
#      'levelCode': 3},
#     {'name': 'Russian',
#      'level': 'First language',
#      'code': 'ru',
#      'levelCode': 5},
#     {'name': 'German', 'level': 'Fluent', 'code': 'de', 'levelCode': 4}],
#    'jobs': [{'jobTitle': '<mark>Software</mark> <mark>Engineer</mark>',
#      'periodStart': '2020-04-01T00:00:00.000Z',
#      'company': 'KARL STORZ SE & Co. KG'},
#     {'jobTitle': 'Senior <mark>Software</mark> <mark>Engineer</mark>',
#      'periodStart': '2017-10-01T00:00:00.000Z',
#      'periodEnd': '2020-03-31T23:59:59.000Z',
#      'company': 'COMPLEVO GmbH',
#      'industryCode': '008'},
#     {'jobTitle': '.NET <mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2017-06-01T00:00:00.000Z',
#      'periodEnd': '2017-10-31T23:59:59.000Z',
#      'company': 'Mitto AG',
#      'industryCode': '023'},
#     {'jobTitle': '.NET <mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2015-08-01T00:00:00.000Z',
#      'periodEnd': '2017-06-30T23:59:59.000Z',
#      'company': 'EffectiveSoft',
#      'industryCode': '002'},
#     {'jobTitle': '.NET <mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2012-01-01T00:00:00.000Z',
#      'periodEnd': '2015-08-31T23:59:59.000Z',
#      'company': 'Itransition'},
#     {'jobTitle': '.NET <mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2011-09-01T00:00:00.000Z',
#      'periodEnd': '2012-01-31T23:59:59.000Z',
#      'company': 'CodingStaff'}],
#    'education': [{'school': 'Belarusian State University of Informatics and Radioelectronics',
#      'periodStart': '2008-09-01T00:00:00.000Z',
#      'periodEnd': '2013-06-30T23:59:59.000Z',
#      'study': 'Software Engineering'}],
#    'gender': 'm',
#    'hasEmail': False,
#    'hasPhone': False,
#    'hasFax': False,
#    'profileQuality': 85,
#    'changeProbability': 45,
#    'expertise': 50,
#    'mobility': 20,
#    'contactability': 60,
#    'monthsInJob': 18,
#    'monthsWorking': 122,
#    '_hideInSearch': False,
#    'lastEmployDate': '2020-04-01T00:00:00.000Z',
#    'lastScraped': '2021-10-03T10:32:24.392Z',
#    'lastUpdated': '2021-10-12T11:14:34.829Z',
#    'isFreelancer': False,
#    'isConsultant': False,
#    'isRecruiter': False,
#    'isEntrepreneur': False,
#    'isTrainee': False,
#    'isIntern': False,
#    'isStudent': False,
#    'isPupil': False,
#    'isSpeaker': False,
#    'isScientist': False,
#    'ml5': {'similarProfiles': {'encoding': ['pos0cluster22',
#       'pos1cluster7',
#       'pos2cluster22',
#       'pos3cluster13',
#       'pos4cluster30',
#       'pos5cluster1',
#       'pos6cluster4',
#       'pos7cluster23',
#       'pos8cluster4',
#       'pos9cluster7',
#       'pos10cluster12',
#       'pos11cluster10',
#       'pos12cluster12',
#       'pos13cluster1',
#       'pos14cluster16',
#       'pos15cluster20',
#       'pos16cluster12',
#       'pos17cluster6',
#       'pos18cluster1',
#       'pos19cluster7']},
#     'profileQuality': 7},
#    '_id': 'aHR0cHM6Ly93d3cueGluZy5jb20vcHJvZmlsZS9JbWFudHNfUGFyc2p1a2V2aWNz',
#    'relevance': 99},
#   {'_class': 'xing',
#    'profileURL': 'https://www.xing.com/profile/Muhammad_Farhan16',
#    'uid': '5c40bd8b46e0fb001adaa6cf',
#    'handle': 'muhammad_farhan16',
#    'imageURL': 'https://profile-images.xing.com/images/8a1474cf5ff1dd905d488f75db827c76-3/muhammad-farhan.256x256.jpg',
#    'fullName': 'Muhammad Farhan',
#    'name': 'Muhammad Farhan',
#    'firstName': 'Muhammad',
#    'lastName': 'Farhan',
#    'geoPoint': {'lat': 52.52000659999999, 'lon': 13.404954},
#    'address': {'countryCode': 'de',
#     'country': 'Deutschland',
#     'state': '6.0',
#     'city': 'Berlin'},
#    'location': '<mark>Berlin</mark>, Germany',
#    'jobTitle': '<mark>Software</mark> <mark>Developer</mark>',
#    'previousJobTitles': ['<mark>Software</mark> <mark>Engineer</mark>',
#     'Trainee <mark>Software</mark> <mark>Engineer</mark>',
#     'Software Quality Assurance Engineer'],
#    'industry': 'Angestellt, Software Developer, Berlin Brands Group',
#    'company': '<mark>Berlin</mark> Brands Group',
#    'previousCompanies': ['DatumSquare IT Services',
#     'Estrats',
#     'Celestia Software',
#     'LMKT'],
#    'bio': 'is working from home. 🏡',
#    'skills': ['C#',
#     'ASP.NET',
#     'SQL',
#     '<mark>C#.NET</mark>',
#     'MVC',
#     'MySQL',
#     'Angular',
#     'Bootstrap (front-end framework)',
#     'Object Oriented Programming',
#     'JavaScript',
#     'jQuery',
#     'ES6',
#     'Software Development',
#     '<mark>.NET</mark> <mark>Framework</mark>',
#     'Microsoft',
#     '<mark>WPF</mark>',
#     'Visual Studio',
#     'ASP',
#     'Microsoft Azure',
#     '<mark>Model-view-controller</mark> (<mark>MVC</mark>)',
#     '<mark>Entity</mark> <mark>Framwork</mark>',
#     'ORM',
#     'MVVM',
#     'CSS'],
#    'languagesString': 'English en',
#    'languages': [{'name': 'English',
#      'level': 'Fluent',
#      'code': 'en',
#      'levelCode': 4}],
#    'jobs': [{'jobTitle': '<mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2021-02-01T00:00:00.000Z',
#      'company': 'Berlin Brands Group',
#      'industryCode': '002',
#      'notes': '- Responsible for Maintenance of existing modules and enhancement of new modules in different Web (Asp.Net MVC) applications. - Taking part as a Full Stack Web <mark>Developer</mark> from Requirement Engineering to Deployment. - Communicating and Coordinating with Clients and Team'},
#     {'jobTitle': '<mark>Software</mark> <mark>Engineer</mark>',
#      'periodStart': '2018-01-01T00:00:00.000Z',
#      'periodEnd': '2021-01-31T23:59:59.000Z',
#      'company': 'DatumSquare IT Services',
#      'notes': 'o Development of new modules using HTML5, CSS3, Kendo UI Core, MVC, Web APIs and Web Hooks o Enhancement in existing modules o Bugs Fixations and maintenance of web apps and concerning databases o Development of Restful APIs o SQL server and Database Management o Daily and Weekly Releases on Microsoft Azure o Daily SCRUM Meetings with Product Owner o Suggest new changes and workflows to Product Owner'},
#     {'jobTitle': '<mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2017-03-01T00:00:00.000Z',
#      'periodEnd': '2018-01-31T23:59:59.000Z',
#      'company': 'Estrats',
#      'notes': '- Responsible for Maintenance of existing modules and enhancement of new modules in different Web (Asp.Net MVC) applications. - Taking part as a Full Stack Web <mark>Developer</mark> from Requirement Engineering to Deployment. - Communicating and Coordinating with Clients and Team'},
#     {'jobTitle': 'Trainee <mark>Software</mark> <mark>Engineer</mark>',
#      'periodStart': '2016-11-01T00:00:00.000Z',
#      'periodEnd': '2017-02-28T23:59:59.000Z',
#      'company': 'Celestia Software',
#      'notes': '- Worked majorly in Microsoft technologies like C#, ASP.Net, SQL Server, MySql, HTML 5, CSS, JavaScript, jQuery, Ajax to build Websites and Enterprise Web Solutions for a diverse group of Clients across the world. - Managed products in Web Forms (Medical + HealthCare) and build new projects using MVC.'},
#     {'jobTitle': 'Software Quality Assurance Engineer',
#      'periodStart': '2016-09-01T00:00:00.000Z',
#      'periodEnd': '2016-11-30T23:59:59.000Z',
#      'company': 'LMKT',
#      'notes': '• Majorly worked in automation of Web, Android and iOS Applications. Automated several projects using JAVA, Selenium, Selendroid and Appium. Deployed Test Suites on TFS On-Premise and Amazon (AWS) Mobile Hub. • Deployed Test Suites as Continuous Integrations on CI Servers like Jenkins. Also worked in Calabash Framework for automation of iOS applications. EDUCATION'}],
#    'education': [{'school': 'Bahria University, Islamabad',
#      'periodStart': '2012-09-01T00:00:00.000Z',
#      'periodEnd': '2016-06-30T23:59:59.000Z',
#      'study': 'Software Engineering',
#      'notes': 'Computer Programming, Software Engineering, Software Project Management'}],
#    'gender': 'm',
#    'hasEmail': False,
#    'hasPhone': False,
#    'hasFax': False,
#    'profileQuality': 89,
#    'changeProbability': 35,
#    'expertise': 40,
#    'mobility': 10,
#    'contactability': 60,
#    'monthsInJob': 8,
#    'monthsWorking': 61,
#    '_hideInSearch': False,
#    'lastEmployDate': '2021-02-01T00:00:00.000Z',
#    'lastScraped': '2021-10-03T12:36:23.130Z',
#    'lastUpdated': '2021-10-12T13:01:27.841Z',
#    'isFreelancer': False,
#    'isConsultant': False,
#    'isRecruiter': False,
#    'isEntrepreneur': False,
#    'isTrainee': False,
#    'isIntern': False,
#    'isStudent': False,
#    'isPupil': False,
#    'isSpeaker': False,
#    'isScientist': False,
#    'ml5': {'similarProfiles': {'encoding': ['pos0cluster22',
#       'pos1cluster7',
#       'pos2cluster22',
#       'pos3cluster26',
#       'pos4cluster30',
#       'pos5cluster1',
#       'pos6cluster4',
#       'pos7cluster23',
#       'pos8cluster4',
#       'pos9cluster7',
#       'pos10cluster12',
#       'pos11cluster10',
#       'pos12cluster12',
#       'pos13cluster1',
#       'pos14cluster16',
#       'pos15cluster20',
#       'pos16cluster12',
#       'pos17cluster6',
#       'pos18cluster1',
#       'pos19cluster7']},
#     'profileQuality': 7},
#    '_id': 'aHR0cHM6Ly93d3cueGluZy5jb20vcHJvZmlsZS9NdWhhbW1hZF9GYXJoYW4xNg',
#    'relevance': 98},
#   {'_class': 'xing',
#    'profileURL': 'https://www.xing.com/profile/Emeka_Onwuzulike',
#    'uid': '6005ca15a9828243be0df0a2',
#    'handle': 'emeka_onwuzulike',
#    'imageURL': 'https://profile-images.xing.com/images/108f1445073236f5dd80e96846b029a3-1/emeka-onwuzulike.256x256.jpg',
#    'fullName': 'Emeka Onwuzulike',
#    'name': 'Emeka Onwuzulike',
#    'firstName': 'Emeka',
#    'lastName': 'Onwuzulike',
#    'geoPoint': {'lat': 52.52000659999999, 'lon': 13.404954},
#    'address': {'countryCode': 'de',
#     'country': 'Deutschland',
#     'state': '6.0',
#     'city': 'Berlin'},
#    'location': '<mark>Berlin</mark>, Germany',
#    'jobTitle': '<mark>Software</mark> <mark>Engineer</mark>',
#    'previousJobTitles': ['<mark>Senior</mark> <mark>Software</mark> <mark>Engineer</mark>'],
#    'industry': 'Employee, Software Engineer, Verivox GmbH',
#    'company': 'Verivox GmbH',
#    'previousCompanies': ['HelloFreshGO', 'GitStart', 'Nextekk LLC'],
#    'skills': ['C#',
#     'JavaScript',
#     'HTML',
#     'CSS',
#     '<mark>.NET</mark> <mark>Framework</mark>',
#     'Software Development',
#     'Apache Kafka.',
#     '<mark>Asp.net</mark> <mark>Core</mark>',
#     'Node.js',
#     'Vuejs',
#     '<mark>Angular</mark>',
#     'Bootstrap',
#     '<mark>Entity</mark> <mark>Framwork</mark>',
#     '<mark>React</mark> JS',
#     'Kubernetes',
#     'Terraform',
#     'Azure',
#     'Docker',
#     'PostgreSQL',
#     'MS-SQL-Server',
#     'Java-Script',
#     'TypeScript',
#     'Helm',
#     'Flux',
#     'MongoDB'],
#    'jobs': [{'jobTitle': '<mark>Software</mark> <mark>Engineer</mark>',
#      'periodStart': '2021-02-01T00:00:00.000Z',
#      'company': 'Verivox GmbH',
#      'industryCode': '019',
#      'notes': '• Managed the maintenance of the old Coherent platform and the development of the new Coherent Factory Platform, a platform for managing health insurance data. • Managed the Development of televeda, a social service video meeting application. • Managed the Development of Haybeat, an online job portal for the Indian market. • Worked on the development of a task Synchronizer/Management Portal/Application used internally by the company.'},
#     {'jobTitle': 'Senior <mark>Software</mark> <mark>Engineer</mark>',
#      'periodStart': '2020-01-01T00:00:00.000Z',
#      'periodEnd': '2020-07-31T23:59:59.000Z',
#      'company': 'HelloFreshGO',
#      'industryCode': '001',
#      'notes': '• Championed the design and development of the customer facing portal and admin BackOffice user Interface using Blazor Web Framework. • Involve in the architectural design and implementation of the fridge IOT device and how it interacts with the micro-services. • Designed and Developed new features in the micro services putting into consideration high scalability, resiliency and availability. • Writing acceptance integration and unit tests that serves as regression tests for the micro services.'},
#     {'jobTitle': '<mark>Software</mark> <mark>Engineer</mark>',
#      'periodStart': '2018-12-01T00:00:00.000Z',
#      'periodEnd': '2019-12-31T23:59:59.000Z',
#      'company': 'GitStart',
#      'notes': '• Managed the maintenance of the old Coherent platform and the development of the new Coherent Factory Platform, a platform for managing health insurance data. • Managed the Development of televeda, a social service video meeting application. • Managed the Development of Haybeat, an online job portal for the Indian market. • Worked on the development of a task Synchronizer/Management Portal/Application used internally by the company.'},
#     {'jobTitle': '<mark>Software</mark> <mark>Engineer</mark>',
#      'periodStart': '2017-01-01T00:00:00.000Z',
#      'periodEnd': '2019-07-31T23:59:59.000Z',
#      'company': 'Nextekk LLC',
#      'notes': '•Lead a team building a scalable, real-time, customer facing quiz application. •Assisted in the design development of a task scheduling/management system for a Company in Florida, USA. •Lead a team to build a Centralized login logic and workflow(Authentication as a service) for all of your applications using Identity server 4. •Worked with a team that developed an Operations Application (Time tracking, Client management, Project management, Cash Flow management and Asset management) used by the company.'}],
#    'education': [{'school': 'Ahmadu Bello University',
#      'periodStart': '2008-01-01T00:00:00.000Z',
#      'periodEnd': '2014-05-31T23:59:59.000Z',
#      'study': 'Water Resources and Environmental Engineering'}],
#    'gender': 'm',
#    'hasEmail': False,
#    'hasPhone': False,
#    'hasFax': False,
#    'changeProbability': 35,
#    'mobility': 5,
#    'monthsInJob': 8,
#    'monthsWorking': 51,
#    '_hideInSearch': False,
#    'lastScraped': '2021-10-08T18:16:48.856Z',
#    'lastUpdated': '2021-10-14T09:24:32.342Z',
#    'isFreelancer': False,
#    'isConsultant': False,
#    'isRecruiter': False,
#    'isEntrepreneur': False,
#    'isStudent': False,
#    'isScientist': False,
#    'ml5': {'similarProfiles': {'encoding': ['pos0cluster22',
#       'pos1cluster7',
#       'pos2cluster22',
#       'pos3cluster13',
#       'pos4cluster30',
#       'pos5cluster1',
#       'pos6cluster4',
#       'pos7cluster23',
#       'pos8cluster4',
#       'pos9cluster7',
#       'pos10cluster12',
#       'pos11cluster10',
#       'pos12cluster12',
#       'pos13cluster1',
#       'pos14cluster16',
#       'pos15cluster20',
#       'pos16cluster12',
#       'pos17cluster24',
#       'pos18cluster1',
#       'pos19cluster7']},
#     'profileQuality': 7},
#    '_id': 'aHR0cHM6Ly93d3cueGluZy5jb20vcHJvZmlsZS9FbWVrYV9Pbnd1enVsaWtl',
#    'relevance': 95},
#   {'_class': 'xing',
#    'profileURL': 'https://www.xing.com/profile/Ice_Jovanoski4',
#    'uid': '5fa02ff9ae51184a66d6942e',
#    'handle': 'ice_jovanoski4',
#    'imageURL': 'https://profile-images.xing.com/images/22aace920f31776136e6a901e1f0fb51-2/ice-jovanoski.256x256.jpg',
#    'fullName': 'Ice Jovanoski',
#    'name': 'Ice Jovanoski',
#    'firstName': 'Ice',
#    'lastName': 'Jovanoski',
#    'geoPoint': {'lat': 52.52000659999999, 'lon': 13.404954},
#    'address': {'countryCode': 'de',
#     'country': 'Deutschland',
#     'state': '6.0',
#     'city': 'Berlin'},
#    'location': '<mark>Berlin</mark>, Germany',
#    'jobTitle': '<mark>Software</mark> <mark>Engineer</mark>',
#    'previousJobTitles': ['Lead <mark>Software</mark> <mark>Engineer</mark>',
#     'Xamarin team lead',
#     '<mark>Software</mark> <mark>developer</mark>'],
#    'industry': 'Employee, Software Engineer, Mister Spex',
#    'company': 'Mister Spex',
#    'previousCompanies': ['ScaleFocus', 'Kubikos', 'F5 Tech', 'HASELT'],
#    'skills': ['<mark>.NET</mark> <mark>Framework</mark>',
#     'JavaScript',
#     'C#',
#     'SQL Server',
#     '<mark>WPF</mark>',
#     'MVC',
#     'HTML',
#     'CSS',
#     'Solution',
#     'Angular',
#     'Software Development',
#     'Java-Script',
#     'JS',
#     'JSON',
#     'Vue.js',
#     'C++',
#     'TypeScript',
#     'Dart',
#     'Dart (programming language)',
#     'Flutter',
#     '.NET',
#     '<mark>Microsoft</mark> <mark>.NET</mark>',
#     '.NET Core',
#     'ASP.NET',
#     '<mark>ASP.NET</mark> <mark>Core</mark>',
#     'C#.NET',
#     'c#',
#     '<mark>C#</mark> <mark>Development</mark>',
#     'C# Entwicklung',
#     'C#-Entwicklung',
#     'HTML5',
#     'CSS3',
#     'Knockout.js',
#     'Angular2',
#     'jQuery',
#     'Bootstrap (front-end framework)',
#     'Ajax',
#     'XML',
#     'XAML',
#     'Xamarin',
#     'Xamarin.Forms',
#     'MongoDB',
#     'PostgreSQL',
#     'Azure',
#     'Microsoft Azure',
#     'NoSQL',
#     'SQL',
#     'Mobile Development',
#     'Cross-platform',
#     'SPA',
#     'API'],
#    'languagesString': 'English en',
#    'languages': [{'name': 'English',
#      'level': 'Fluent',
#      'code': 'en',
#      'levelCode': 4}],
#    'jobs': [{'jobTitle': '<mark>Software</mark> <mark>Engineer</mark>',
#      'periodStart': '2021-06-01T00:00:00.000Z',
#      'company': 'Mister Spex',
#      'industryCode': '002'},
#     {'jobTitle': '<mark>Software</mark> <mark>Engineer</mark>',
#      'periodStart': '2020-12-01T00:00:00.000Z',
#      'periodEnd': '2021-03-31T23:59:59.000Z',
#      'company': 'ScaleFocus',
#      'industryCode': '002'},
#     {'jobTitle': 'Lead <mark>Software</mark> <mark>Engineer</mark>',
#      'periodStart': '2018-12-01T00:00:00.000Z',
#      'periodEnd': '2020-10-31T23:59:59.000Z',
#      'company': 'Kubikos',
#      'notes': '- Design architecture for .NET Core API solutions - Design architecture for <mark>Angular</mark> 2+ SPA solutions - Responsible for maintaining the development stack + knowledge sharing with the development team with peer education & tech talks'},
#     {'jobTitle': 'Xamarin team lead',
#      'periodStart': '2017-09-01T00:00:00.000Z',
#      'periodEnd': '2018-11-30T23:59:59.000Z',
#      'company': 'F5 Tech',
#      'notes': '- Design architecture for ASP.NET MVC & Web Api solutions - Design architecture for <mark>Xamarin.Forms</mark> solution focusing iOS & Android - Lead a team of 4 developers on the <mark>Xamarin.Forms</mark> solution - Deployment, monitoring and maintenance on both iOS and Android apps using Vistual Studio AppCenter - Research and development for pre-release versions with <mark>Xamarin.Forms</mark> and other dependent packages - Create team development strategy for helping others learn / advance further with using Xamarin technologies'},
#     {'jobTitle': '<mark>Software</mark> <mark>developer</mark>',
#      'periodStart': '2014-11-01T00:00:00.000Z',
#      'periodEnd': '2017-08-31T23:59:59.000Z',
#      'company': 'HASELT',
#      'notes': '- Design and develop highly reliable, maintainable and secure software solutions - Deploy, monitor and maintain production applications - Involve in development across the full system stack - Balance long term code health and maintainability with business needs - Collaborate with managers, customers and technical leads to develop use cases and specifications that describe the needs for a software project'}],
#    'education': [{'school': 'Seavus Education and Development Center',
#      'periodStart': '2014-10-01T00:00:00.000Z',
#      'periodEnd': '2015-09-30T23:59:59.000Z',
#      'study': 'Web Development and Cloud Engineering',
#      'notes': '- Fullstack development of ASP.NET MVC & API apps. - Front-end JavaScript development - Azure Cloud solutions development - SPA development for Angular apps'},
#     {'school': 'Mikrosam Academy',
#      'periodStart': '2012-06-01T00:00:00.000Z',
#      'periodEnd': '2014-09-30T23:59:59.000Z',
#      'study': 'C++ software engineer',
#      'notes': '- Low level programming for IoT devices with focus on performance and memory management - Applied mathematics. Implementation of most commonly used principles in the area of robotics & gaming using MATLAB.'}],
#    'gender': 'm',
#    'hasEmail': False,
#    'hasPhone': False,
#    'hasFax': False,
#    'changeProbability': 35,
#    'mobility': 10,
#    'monthsInJob': 4,
#    'monthsWorking': 80,
#    '_hideInSearch': False,
#    'lastScraped': '2021-10-11T03:03:28.408Z',
#    'lastUpdated': '2021-10-15T07:26:23.354Z',
#    'isFreelancer': False,
#    'isConsultant': False,
#    'isRecruiter': False,
#    'isEntrepreneur': False,
#    'isStudent': False,
#    'isScientist': False,
#    'ml5': {'similarProfiles': {'encoding': ['pos0cluster22',
#       'pos1cluster7',
#       'pos2cluster3',
#       'pos3cluster13',
#       'pos4cluster30',
#       'pos5cluster1',
#       'pos6cluster4',
#       'pos7cluster23',
#       'pos8cluster4',
#       'pos9cluster7',
#       'pos10cluster12',
#       'pos11cluster10',
#       'pos12cluster12',
#       'pos13cluster1',
#       'pos14cluster16',
#       'pos15cluster20',
#       'pos16cluster12',
#       'pos17cluster6',
#       'pos18cluster1',
#       'pos19cluster7']},
#     'profileQuality': 7},
#    '_id': 'aHR0cHM6Ly93d3cueGluZy5jb20vcHJvZmlsZS9JY2VfSm92YW5vc2tpNA',
#    'relevance': 92},
#   {'_class': 'xing',
#    'profileURL': 'https://www.xing.com/profile/Mohammad_AlHammouri',
#    'uid': '5b1a238446e0fb0012d0da90',
#    'handle': 'mohammad_alhammouri',
#    'imageURL': 'https://profile-images.xing.com/images/801282cc69eaa2a9332f4bdfef462e3a-1/mohammad-al-hammouri.256x256.jpg',
#    'fullName': 'Mohammad Al Hammouri',
#    'name': 'Mohammad Al Hammouri',
#    'firstName': 'Mohammad',
#    'middleName': 'Al',
#    'lastName': 'Hammouri',
#    'geoPoint': {'lat': 52.52000659999999, 'lon': 13.404954},
#    'address': {'countryCode': 'de',
#     'country': 'Deutschland',
#     'state': '6.0',
#     'city': 'Berlin'},
#    'location': '<mark>Berlin</mark>, Germany',
#    'jobTitle': 'IT Consultant / Application <mark>Developer</mark>',
#    'previousJobTitles': ['IT Consultant / Application <mark>Developer</mark> (Dynamics CRM)',
#     '<mark>.NET</mark> <mark>Developer</mark>',
#     'Systems analyst and <mark>.NET</mark> <mark>Developer</mark>',
#     'Programs Officer',
#     '.Net <mark>Software</mark> <mark>Developer</mark>'],
#    'industry': 'Until 2021, IT Consultant / Application Developer, proMX AG',
#    'company': 'proMX AG',
#    'previousCompanies': ['ProLAN Datensysteme GmbH',
#     'Dynamics Consulting GmbH',
#     'freelancer',
#     'Al Sahara Houlding Group  ICT Systems',
#     'KAFD  GamingLab',
#     'Jadwa for business solutions'],
#    'skills': ['Microsoft Dynamics CRM',
#     'MS Dynamics CRM',
#     '<mark>.NET</mark> <mark>Framework</mark>',
#     'MVC',
#     'API',
#     'Microsoft SQL-Server Reporting Services',
#     '<mark>Object</mark> <mark>Oriented</mark> <mark>Programming</mark> (<mark>OOP</mark>)',
#     '<mark>Entity</mark> <mark>Framwork</mark>',
#     'JavaScript',
#     '<mark>React</mark>',
#     'Data Structures',
#     'Systems analysis',
#     'Bootstrap (front-end framework)',
#     'Microsoft SQL Server',
#     'Apache Cordova',
#     'Unity3D',
#     'Construct 2',
#     'Research'],
#    'languagesString': 'Arabic ar English en German de',
#    'languages': [{'name': 'Arabic',
#      'level': 'First language',
#      'code': 'ar',
#      'levelCode': 5},
#     {'name': 'English', 'level': 'Fluent', 'code': 'en', 'levelCode': 4},
#     {'name': 'German', 'level': 'Basic', 'code': 'de', 'levelCode': 2}],
#    'jobs': [{'jobTitle': 'IT Consultant / Application <mark>Developer</mark>',
#      'periodStart': '2021-02-01T00:00:00.000Z',
#      'periodEnd': '2021-05-31T23:59:59.000Z',
#      'company': 'proMX AG',
#      'industryCode': '002'},
#     {'jobTitle': 'IT Consultant / Application <mark>Developer</mark> (Dynamics CRM)',
#      'periodStart': '2018-09-01T00:00:00.000Z',
#      'periodEnd': '2021-01-31T23:59:59.000Z',
#      'company': 'ProLAN Datensysteme GmbH',
#      'industryCode': '002'},
#     {'jobTitle': 'IT Consultant / Application <mark>Developer</mark> (Dynamics CRM)',
#      'periodStart': '2017-10-01T00:00:00.000Z',
#      'periodEnd': '2018-09-30T23:59:59.000Z',
#      'company': 'Dynamics Consulting GmbH',
#      'industryCode': '002'},
#     {'jobTitle': '<mark>.NET</mark> <mark>Developer</mark>',
#      'periodStart': '2017-02-01T00:00:00.000Z',
#      'periodEnd': '2017-07-31T23:59:59.000Z',
#      'company': 'freelancer',
#      'notes': 'Building application for both individual clients or helping IT companies with their applications using .Net Framework.'},
#     {'jobTitle': 'Systems analyst and <mark>.NET</mark> <mark>Developer</mark>',
#      'periodStart': '2015-02-01T00:00:00.000Z',
#      'periodEnd': '2016-12-31T23:59:59.000Z',
#      'company': 'Al Sahara Houlding Group  ICT Systems',
#      'notes': 'Developing web based applications for this projects: 1- Al-Baha Municipality Inspection System. 2- IT Consultant for RASD System at Jeddah Municipality. 3- Al Sahara Archiving System 4- ADA (High commission for the development of Arriyadh) inspection system for counting the unlicensed factories in Al Riyadh more details about each project existed on my CV.'},
#     {'jobTitle': 'Programs Officer',
#      'periodStart': '2013-11-01T00:00:00.000Z',
#      'periodEnd': '2015-01-31T23:59:59.000Z',
#      'company': 'KAFD  GamingLab',
#      'notes': 'Duties: • Manage and run the lab in in the northern cities. • Organize all the lectures in the lab. • Communicate with universities administrations and lecturers to involve their students with our activities. • Manage and organize annual events like Jordan Gamming Summit, AppChallenge competition and SouthCamp. • Manage and Organize universal events like GlobalGameJam, Zanga competition and AppCircus. • Games programming trainers in XNA, Unity and Construct2 games engines.'},
#     {'jobTitle': '.Net <mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2012-10-01T00:00:00.000Z',
#      'periodEnd': '2013-01-31T23:59:59.000Z',
#      'company': 'Jadwa for business solutions',
#      'notes': 'ERP <mark>Developer</mark> using .NET Framework.'}],
#    'education': [{'school': 'Al-Hussein Bin Talal University',
#      'periodStart': '2007-06-01T00:00:00.000Z',
#      'periodEnd': '2011-06-30T23:59:59.000Z',
#      'study': 'Computer Science'}],
#    'gender': 'm',
#    'hasEmail': False,
#    'hasPhone': False,
#    'hasFax': False,
#    'changeProbability': 35,
#    'mobility': 20,
#    'monthsInJob': 3,
#    'monthsWorking': 91,
#    '_hideInSearch': False,
#    'lastScraped': '2021-10-18T06:17:19.881Z',
#    'lastUpdated': '2021-10-18T09:14:50.661Z',
#    'isFreelancer': False,
#    'isConsultant': False,
#    'isRecruiter': False,
#    'isEntrepreneur': False,
#    'isStudent': False,
#    'isScientist': False,
#    'ml5': {'similarProfiles': {'encoding': ['pos0cluster22',
#       'pos1cluster7',
#       'pos2cluster22',
#       'pos3cluster26',
#       'pos4cluster7',
#       'pos5cluster1',
#       'pos6cluster20',
#       'pos7cluster23',
#       'pos8cluster4',
#       'pos9cluster7',
#       'pos10cluster12',
#       'pos11cluster0',
#       'pos12cluster3',
#       'pos13cluster1',
#       'pos14cluster16',
#       'pos15cluster20',
#       'pos16cluster12',
#       'pos17cluster6',
#       'pos18cluster1',
#       'pos19cluster7']},
#     'profileQuality': 7},
#    '_id': 'aHR0cHM6Ly93d3cueGluZy5jb20vcHJvZmlsZS9Nb2hhbW1hZF9BbEhhbW1vdXJp',
#    'relevance': 91},
#   {'_class': 'xing',
#    'profileURL': 'https://www.xing.com/profile/behzad_bagherian2',
#    'uid': '5c2457b746e0fb001a776ff1',
#    'handle': 'behzad_bagherian2',
#    'imageURL': 'https://profile-images.xing.com/images/f03d536412c977a92d4fa99c50208eef-1/behzad-bagherian.256x256.jpg',
#    'fullName': 'Behzad Bagherian',
#    'name': 'Behzad Bagherian',
#    'firstName': 'Behzad',
#    'lastName': 'Bagherian',
#    'geoPoint': {'lat': 52.52000659999999, 'lon': 13.404954},
#    'address': {'countryCode': 'de',
#     'country': 'Deutschland',
#     'state': '6.0',
#     'city': 'Berlin'},
#    'location': '<mark>Berlin</mark>, Germany',
#    'jobTitle': '<mark>Senior</mark> <mark>Software</mark> <mark>Engineer</mark>',
#    'previousJobTitles': ['FullStack <mark>Developer</mark>',
#     '<mark>Senior</mark> <mark>Software</mark> <mark>Developer</mark>'],
#    'industry': 'Employee, FullStack Developer, Caspian',
#    'company': 'Emproc sys GmbH',
#    'previousCompanies': ['Caspian',
#     'Seyagh Software Solution',
#     'Tazarv Afzar'],
#    'skills': ['<mark>C#.NET</mark>',
#     '<mark>Angular</mark>',
#     'React.js',
#     '<mark>TypeScript</mark>',
#     '.Net Core',
#     'ASP.NET',
#     'JavaScript',
#     'CSS',
#     'HTML',
#     'RxJs',
#     'Webpack',
#     'NPM',
#     'T-SQL',
#     '<mark>REST</mark> <mark>API</mark>',
#     'XML',
#     'JSON',
#     'NUNIT',
#     'SCRUM',
#     'MVC',
#     'MVVM',
#     '<mark>Angular</mark> CLI',
#     'Bootstrap (front-end framework)',
#     'Software Development',
#     'Vue.js',
#     'Vuejs'],
#    'languagesString': 'English en German de',
#    'languages': [{'name': 'English',
#      'level': 'Fluent',
#      'code': 'en',
#      'levelCode': 4},
#     {'name': 'German', 'level': 'Basic', 'code': 'de', 'levelCode': 2}],
#    'jobs': [{'jobTitle': '<mark>Senior</mark> <mark>Software</mark> <mark>Engineer</mark>',
#      'periodStart': '2020-05-01T00:00:00.000Z',
#      'company': 'Emproc sys GmbH',
#      'notes': 'Developing Project controlling software PROBIS. Key Technologies: C#,<mark>WPF</mark>,Prism,MVVM,SQL,.Netcore ,<mark>REST</mark> <mark>API</mark> ,SCRUM,Jira,Git,SOLID,DevExpress'},
#     {'jobTitle': 'FullStack <mark>Developer</mark>',
#      'periodStart': '2015-11-01T00:00:00.000Z',
#      'company': 'Caspian',
#      'industryCode': '003',
#      'notes': 'Developing core banking with the brand of Lotus, and also work on some other project related to financial market like SWIFT, Direct Debit, Trade Finance, etc. In our team, we use the Scrum methodology for software development project management. As a Full-stack developer. I work with (<mark>Angular</mark> 7+,ReactJs) for front-end and C#, Dot net core 2.2 for the desktop. • <mark>Angular</mark> 8 ,ReactJs Webpack-NPM -TypeScript(JavaScript - ES6) • C# -WPF - <mark>ASP.NET</mark> <mark>Core</mark> 2.2 <mark>Rest</mark> <mark>API</mark> -SQL Server, T-SQL -EF6'},
#     {'jobTitle': '<mark>Senior</mark> <mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2012-03-01T00:00:00.000Z',
#      'periodEnd': '2015-10-31T23:59:59.000Z',
#      'company': 'Seyagh Software Solution',
#      'notes': '• Angular-TypeScript-JavaScript - • JQuery - ES6 - Ajax - BootStarp - HTML5 - CSS3 • C# - ASP - MVC -EF6 -NUnit - XUnit - SOLID -Clean code • Agile (Scrum) Responsibilities: Design, create, deploy Software system related to Accounting - HR - Salary - Inventory Working on a desktop Accounting system to convert it to the web application and also developing some financial and office web base application with <mark>Angular</mark> 2'},
#     {'jobTitle': '<mark>Senior</mark> <mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2008-09-01T00:00:00.000Z',
#      'periodEnd': '2012-03-31T23:59:59.000Z',
#      'company': 'Tazarv Afzar',
#      'notes': 'Working on tools that make end-user happy to generate their own forms by themselves and then design their workflow. Everything happens only by drag and drop controls to the form generator, to make your mind in application forms and then you have to design your workflow and it is ready to use in your company. this tool has consisted of several parts like form generator workflow designer, report designer and also a task manager. • C# 3.5 - EF • <mark>WPF</mark> MVVM • SQL server 2008 • Agile (Scrum)'}],
#    'education': [{'school': 'Universitat fur Angewandte Wissenschaften',
#      'periodStart': '2006-07-01T00:00:00.000Z',
#      'periodEnd': '2010-07-31T23:59:59.000Z',
#      'study': 'Ingenieurwesen für Informationstechnologie (Webprogrammierung)'}],
#    'gender': 'm',
#    'hasEmail': False,
#    'hasPhone': False,
#    'hasFax': False,
#    'profileQuality': 85,
#    'changeProbability': 45,
#    'expertise': 50,
#    'mobility': 15,
#    'contactability': 60,
#    'monthsInJob': 17,
#    'monthsWorking': 159,
#    '_hideInSearch': False,
#    'lastEmployDate': '2020-05-01T00:00:00.000Z',
#    'lastScraped': '2021-10-03T12:27:13.928Z',
#    'lastUpdated': '2021-10-12T12:56:02.719Z',
#    'isFreelancer': False,
#    'isConsultant': False,
#    'isRecruiter': False,
#    'isEntrepreneur': False,
#    'isTrainee': False,
#    'isIntern': False,
#    'isStudent': False,
#    'isPupil': False,
#    'isSpeaker': False,
#    'isScientist': False,
#    'ml5': {'similarProfiles': {'encoding': ['pos0cluster22',
#       'pos1cluster7',
#       'pos2cluster22',
#       'pos3cluster13',
#       'pos4cluster30',
#       'pos5cluster1',
#       'pos6cluster4',
#       'pos7cluster23',
#       'pos8cluster4',
#       'pos9cluster7',
#       'pos10cluster12',
#       'pos11cluster10',
#       'pos12cluster12',
#       'pos13cluster1',
#       'pos14cluster16',
#       'pos15cluster20',
#       'pos16cluster12',
#       'pos17cluster6',
#       'pos18cluster1',
#       'pos19cluster7']},
#     'profileQuality': 7},
#    '_id': 'aHR0cHM6Ly93d3cueGluZy5jb20vcHJvZmlsZS9iZWh6YWRfYmFnaGVyaWFuMg',
#    'relevance': 90},
#   {'_class': 'xing',
#    'profileURL': 'https://www.xing.com/profile/HafizGhazi_Sultan',
#    'uid': '5de7ca9dd855b688ec00ab49',
#    'handle': 'hafizghazi_sultan',
#    'idInPortal': 'HafizGhazi_Sultan',
#    'imageURL': 'https://profile-images.xing.com/images/fefa8e72d52b59e5cde472400c77e1d5-2/hafiz-ghazi-sultan.256x256.jpg',
#    'fullName': 'Hafiz Ghazi Sultan',
#    'name': 'Hafiz Ghazi Sultan',
#    'firstName': 'Hafiz',
#    'middleName': 'Ghazi',
#    'lastName': 'Sultan',
#    'geoPoint': {'lat': 52.52000659999999, 'lon': 13.404954},
#    'address': {'countryCode': 'de',
#     'country': 'Deutschland',
#     'state': '6.0',
#     'city': 'Berlin'},
#    'location': '<mark>Berlin</mark>, Germany',
#    'jobTitle': '<mark>Software</mark> <mark>Developer</mark>',
#    'previousJobTitles': ['<mark>Software</mark> <mark>Engineer</mark>',
#     'FullStack Web <mark>Developer</mark> ( ASP.NET MVC 5)',
#     "Bachelor's Thesis",
#     '<mark>Software</mark> <mark>developer</mark> Internee'],
#    'industry': 'Bis 2019, Software Engineer, IBM',
#    'company': 'University of Rostock',
#    'previousCompanies': ['IBM',
#     'Visual Sparks Technologies',
#     'Techlogix',
#     'Bitstream'],
#    'skills': ['Asp.Net MVC',
#     'Asp.Net Web API',
#     '<mark>Entity</mark> <mark>Framwork</mark>',
#     'Linq',
#     'C#',
#     'SQL Server',
#     'Ajax',
#     'JavaScript',
#     'HTML5',
#     'jQuery',
#     'Blue Prism',
#     'React.js',
#     '<mark>TypeScript</mark>',
#     'GitLab',
#     'Software Development',
#     'Git',
#     'Python',
#     'pyTorch',
#     'Data Warehouse',
#     'TensorFlow',
#     'React Bootstrap',
#     'Heroku',
#     'REST APIs',
#     'MS SQL Server',
#     '.Net Core',
#     '<mark>Asp.Net</mark> <mark>Core</mark>',
#     '<mark>Asp.Net</mark> <mark>Core</mark> MVC',
#     '<mark>ASP.Net</mark> <mark>Core</mark> Web API'],
#    'languagesString': 'English en German de',
#    'languages': [{'name': 'English',
#      'level': 'Fluent',
#      'code': 'en',
#      'levelCode': 4},
#     {'name': 'German', 'level': 'Basic', 'code': 'de', 'levelCode': 2}],
#    'jobs': [{'jobTitle': '<mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2020-07-01T00:00:00.000Z',
#      'company': 'University of Rostock',
#      'industryCode': '010',
#      'notes': 'Extensive Research and Development in automatic identification of research objects mentioned in scientific texts. My tasks are to annotate the scientific publications, then to fine-tune the state of the art models (BioBERT or SciBERT) and rectify my results as much as possible based on the previous scientific studies using Jupyter Notebook, Python, pyTorch, TensorFlow, Keras, huggingface, SciBert, BioBert'},
#     {'jobTitle': '<mark>Software</mark> <mark>Engineer</mark>',
#      'periodStart': '2019-01-01T00:00:00.000Z',
#      'periodEnd': '2019-10-31T23:59:59.000Z',
#      'company': 'IBM',
#      'industryCode': '002',
#      'notes': '- Worked as an application <mark>developer</mark> with IBM South Africa and IBM Dubai - Responsible for designing and developing automated solutions - Worked with International clients on large-scale projects and created fast, automated and more secure software process solutions'},
#     {'jobTitle': 'FullStack Web <mark>Developer</mark> ( ASP.NET MVC 5)',
#      'periodStart': '2017-08-01T00:00:00.000Z',
#      'periodEnd': '2018-09-30T23:59:59.000Z',
#      'company': 'Visual Sparks Technologies',
#      'notes': '- Worked with Dubai and USA teams on multinational projects - Development of different application modules, integration and testing - Ensuring the processes and standards followed in application development - Executed on-time go-live of multiple projects in parallel while training my team ensuring the best quality with minimized testing and delivery times'},
#     {'jobTitle': "Bachelor's Thesis",
#      'periodStart': '2016-08-01T00:00:00.000Z',
#      'periodEnd': '2017-06-30T23:59:59.000Z',
#      'company': 'Techlogix',
#      'industryCode': '002',
#      'notes': "I did my Bachelor's thesis with a well-renowned IT company Techlogix, Pakistan. Purpose of the thesis was to gain insights into educational outcomes of students and university departments as a whole. It is a Machine Learning based, research type project. It used AI algorithms to predict the performance of students and provide them with customized learning materials"},
#     {'jobTitle': '<mark>Software</mark> <mark>developer</mark> Internee',
#      'periodStart': '2016-06-01T00:00:00.000Z',
#      'periodEnd': '2016-08-31T23:59:59.000Z',
#      'company': 'Bitstream',
#      'industryCode': '002',
#      'notes': 'Java Swing and mobile application developer. Products based on Internet of Things and on POS software giving users fully-developed quality products enabling high customer satisfaction'}],
#    'education': [{'school': 'University of Rostock',
#      'periodStart': '2019-10-01T00:00:00.000Z',
#      'study': 'Master in Computer Science',
#      'notes': 'Grade: 1.2 Web development, Requirement Engineering, Human-Computer Interaction, Natural Language Processing, Data Warehousing and Mining, Distributed Algorithms'},
#     {'school': 'Bachelor of Science (Computer Science)',
#      'periodStart': '2013-08-01T00:00:00.000Z',
#      'periodEnd': '2017-06-30T23:59:59.000Z',
#      'study': 'Computer Science',
#      'notes': 'Data Science, Data Warehousing and Mining, Advanced Databases, Artificial Intelligence, Web and Android development, Algorithms, Human-Computer Interaction, Software Engineering and Testing, Data Science, Calculus, Differential Equations, Linear Algebra, Probability and Stats'}],
#    'gender': 'm',
#    'hasEmail': False,
#    'hasPhone': False,
#    'hasFax': False,
#    'changeProbability': 45,
#    'mobility': 15,
#    'monthsInJob': 15,
#    'monthsWorking': 52,
#    '_hideInSearch': False,
#    'lastScraped': '2021-10-20T18:51:29.698Z',
#    'lastUpdated': '2021-10-26T01:46:13.302Z',
#    'isFreelancer': False,
#    'isConsultant': False,
#    'isRecruiter': False,
#    'isEntrepreneur': False,
#    'isStudent': False,
#    'isScientist': False,
#    'ml5': {'similarProfiles': {'encoding': ['pos0cluster22',
#       'pos1cluster7',
#       'pos2cluster22',
#       'pos3cluster13',
#       'pos4cluster30',
#       'pos5cluster1',
#       'pos6cluster4',
#       'pos7cluster23',
#       'pos8cluster4',
#       'pos9cluster7',
#       'pos10cluster12',
#       'pos11cluster10',
#       'pos12cluster12',
#       'pos13cluster1',
#       'pos14cluster16',
#       'pos15cluster20',
#       'pos16cluster12',
#       'pos17cluster6',
#       'pos18cluster1',
#       'pos19cluster7']},
#     'profileQuality': 7},
#    '_id': 'aHR0cHM6Ly93d3cueGluZy5jb20vcHJvZmlsZS9IYWZpekdoYXppX1N1bHRhbg',
#    'relevance': 90},
#   {'_class': 'xing',
#    'profileURL': 'https://www.xing.com/profile/Vladimir_Furso2',
#    'uid': '5e3509e6ffe8cc6b874ca591',
#    'handle': 'vladimir_furso2',
#    'idInPortal': 'Vladimir_Furso2',
#    'imageURL': 'https://profile-images.xing.com/images/fbdb79cde21117f2e50d15dc9203f1a0-1/vladimir-furso.256x256.jpg',
#    'fullName': 'Vladimir Furso',
# ...
#     '<mark>Model-view-controller</mark> (<mark>MVC</mark>)',
#     'JavaScript',
#     'RESTful API',
#     'T-SQL',
#     'AWS Lambda',
#     'Microsoft SQL Server',
#     'LINQ',
#     'SSRS',
#     'Git',
#     'Internet Information Server (IIS)',
#     'jQuery',
#     'Postman',
#     '<mark>Entity</mark> <mark>Framwork</mark>',
#     'Ajax',
#     'JSON',
#     'SOAP',
#     'Gauges',
#     'VS Code',
#     'Contexts and Dependency Injection',
#     'Inversion of Control(IoC)',
#     'Continuous Integration(CI)',
#     'Continuous Delivery(CD)',
#     'Microservices',
#     'Amazon Web Services',
#     'Amazon Dynamodb',
#     'YAML'],
#    'languagesString': 'English en Chinese zh',
#    'languages': [{'name': 'English',
#      'level': 'Fluent',
#      'code': 'en',
#      'levelCode': 4},
#     {'name': 'Chinese',
#      'level': 'First language',
#      'code': 'zh',
#      'levelCode': 5}],
#    'jobs': [{'jobTitle': '<mark>Software</mark> <mark>Engineer</mark>',
#      'periodStart': '2019-04-01T00:00:00.000Z',
#      'company': 'Global Payments',
#      'industryCode': '007',
#      'notes': 'Responsible for developing new features and new services as well as maintaining the existing system. 1. HSM replacement project: replacing the existing credit card record protection method with AWS cloud service. 2. MDES project: enabling MasterCard smart token payment through eWAY payment gateway. 3. Leucocyte project: calling third party fraud detection service to do transaction checking. 4. Rapid API & MYeWAY: Maintaining and enhancing existing apps.'},
#     {'jobTitle': '<mark>Software</mark> <mark>Engineer</mark> & Scheduled Release Engineer',
#      'periodStart': '2017-03-01T00:00:00.000Z',
#      'periodEnd': '2019-04-30T23:59:59.000Z',
#      'company': 'MYP Corporation',
#      'industryCode': '002',
#      'notes': '1. Developed 3 insurance projects for major clients. a. Communicating with clients, defining project requirements. b. Drawing up project development plan: identify project key tasks & estimate project time. c. Project development, testing & delivery. d. Identifying out of scope item and provide cost-effective solutions. e. Maintaining good client relationship. 2. Maintaining and enhancing responsible public module (formSPACE) 3. Scheduled release engineer'},
#     {'jobTitle': 'Application <mark>Developer</mark>',
#      'periodStart': '2016-11-01T00:00:00.000Z',
#      'periodEnd': '2017-03-31T23:59:59.000Z',
#      'company': 'AMET Education',
#      'notes': '• Developing applications for international trade department to automate work process. o Planning and developing product database. o Work automation functions including creating orders, generating purchase list, invoices, storing order history and so on. • Provide consultation to international students regarding to study enquires and immigration solutions. • Lodge Visa & University applications for international students.'},
#     {'jobTitle': 'Graduate <mark>Developer</mark>',
#      'periodStart': '2012-06-01T00:00:00.000Z',
#      'periodEnd': '2016-10-31T23:59:59.000Z',
#      'company': 'Symbio Laboratories',
#      'industryCode': '009',
#      'notes': '• Developing applications & websites to integrate with Biology/Chemistry Lab management system(LIMS) for internal users to achieve work process automation and increase productivity. o Developing applications from initiation to completion. o Using Visual Studio & other techniques to design both back end and front end of the application. o Testing/Debugging. • Maintaining and editing company’s legacy programs and websites according to user’s requirements. • General IT Support'}],
#    'education': [{'school': 'Griffith University',
#      'periodStart': '2010-03-01T00:00:00.000Z',
#      'periodEnd': '2012-01-31T23:59:59.000Z',
#      'study': 'Information Technology',
#      'notes': 'GPA: 6.13 out of 7 – (Equivalent to 1.8 in Germany) Awarded Griffith Award for Academic Excellence 2011'},
#     {'school': 'Mantissa College',
#      'periodStart': '2008-03-01T00:00:00.000Z',
#      'periodEnd': '2009-12-31T23:59:59.000Z',
#      'study': 'Information technology',
#      'notes': 'GPA: 3.43 out of 4 – (Equivalent to 1.8 in Germany) Awarded: Academic Achievement-Best Student in 2009'}],
#    'gender': 'm',
#    'hasEmail': False,
#    'hasPhone': False,
#    'hasFax': False,
#    'changeProbability': 55,
#    'mobility': 15,
#    'monthsInJob': 30,
#    'monthsWorking': 113,
#    '_hideInSearch': False,
#    'lastScraped': '2021-10-11T02:39:58.499Z',
#    'lastUpdated': '2021-10-15T07:18:15.914Z',
#    'isFreelancer': False,
#    'isConsultant': False,
#    'isRecruiter': False,
#    'isEntrepreneur': False,
#    'isStudent': False,
#    'isScientist': False,
#    'ml5': {'similarProfiles': {'encoding': ['pos0cluster22',
#       'pos1cluster7',
#       'pos2cluster22',
#       'pos3cluster26',
#       'pos4cluster30',
#       'pos5cluster14',
#       'pos6cluster20',
#       'pos7cluster17',
#       'pos8cluster4',
#       'pos9cluster7',
#       'pos10cluster12',
#       'pos11cluster10',
#       'pos12cluster12',
#       'pos13cluster1',
#       'pos14cluster1',
#       'pos15cluster20',
#       'pos16cluster12',
#       'pos17cluster24',
#       'pos18cluster1',
#       'pos19cluster7']},
#     'profileQuality': 7},
#    '_id': 'aHR0cHM6Ly93d3cueGluZy5jb20vcHJvZmlsZS9ZaV9TaGVuMjA',
#    'relevance': 73},
#   {'_class': 'xing',
#    'profileURL': 'https://www.xing.com/profile/Mathias_Mueller200',
#    'uid': '5b1a12a946e0fb00123d28e3',
#    'handle': 'mathias_mueller200',
#    'imageURL': 'https://profile-images.xing.com/images/1fa0d7115e8383e982a68d73f7d0f537-3/mathias-m%C3%BCller.256x256.jpg',
#    'fullName': 'Mathias Müller',
#    'name': 'Mathias Müller',
#    'firstName': 'Mathias',
#    'lastName': 'Müller',
#    'geoPoint': {'lat': 52.52000659999999, 'lon': 13.404954},
#    'address': {'countryCode': 'de',
#     'country': 'Deutschland',
#     'state': '6.0',
#     'city': 'Berlin'},
#    'location': '<mark>Berlin</mark>, Germany',
#    'jobTitle': 'Fullstack <mark>Software</mark> <mark>Developer</mark>',
#    'previousJobTitles': ['<mark>Software</mark> <mark>Developer</mark>',
#     'Softwareentwickler .NET',
#     'Teamleiter Anwendungsentwicklung',
#     'Softwareentwickler'],
#    'industry': 'Employee, Fullstack Software Developer, talent360 GmbH',
#    'company': 'talent360 GmbH',
#    'previousCompanies': ['ARGUS DATA INSIGHTS Group',
#     'Anybet GmbH',
#     'IAB Communications GmbH',
#     'ILSS Print&Mail GmbH'],
#    'skills': ['UI',
#     'UX',
#     'Frontend',
#     'UI Design',
#     '<mark>Angular</mark>',
#     '<mark>Typescript</mark>',
#     'HTML',
#     'C#',
#     '.Net Core',
#     '<mark>WPF</mark>',
#     'MVVM',
#     'Kreativität',
#     'Teamfähigkeit',
#     'WCF',
#     'WebServices',
#     'SQL',
#     'Entity Framework',
#     'Python',
#     'Scrum',
#     'Azure DevOps',
#     'Git',
#     'Unit Testing',
#     '<mark>.NET</mark> <mark>Framework</mark>'],
#    'languagesString': 'German de English en',
#    'languages': [{'name': 'German',
#      'level': 'First language',
#      'code': 'de',
#      'levelCode': 5},
#     {'name': 'English',
#      'level': 'Intermediate',
#      'code': 'en',
#      'levelCode': 3}],
#    'jobs': [{'jobTitle': 'Fullstack <mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2019-11-01T00:00:00.000Z',
#      'company': 'talent360 GmbH',
#      'industryCode': '002',
#      'notes': 'C# im <mark>Backend</mark>, <mark>Angular</mark> in Frontend. Entwicklung einer Personal Management Plattform.'},
#     {'jobTitle': '<mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2018-10-01T00:00:00.000Z',
#      'periodEnd': '2019-10-31T23:59:59.000Z',
#      'company': 'ARGUS DATA INSIGHTS Group',
#      'notes': 'Entwicklung von Services (C#) und Frontends (<mark>Angular</mark>)'},
#     {'jobTitle': 'Softwareentwickler .NET',
#      'periodStart': '2016-07-01T00:00:00.000Z',
#      'periodEnd': '2018-09-30T23:59:59.000Z',
#      'company': 'Anybet GmbH',
#      'industryCode': '002',
#      'notes': 'C# / WPF. Entwicklung von Kassensystemen, Touch-Terminals und verteilten System im Retail Bereich von mybet.'},
#     {'jobTitle': 'Teamleiter Anwendungsentwicklung',
#      'periodStart': '2014-05-01T00:00:00.000Z',
#      'periodEnd': '2016-06-30T23:59:59.000Z',
#      'company': 'IAB Communications GmbH',
#      'industryCode': '002',
#      'notes': 'Aufgabenmanagement, Motivation, Lösung von Problemen, Leitung von Besprechungen, Vertretung der Interessen, Softwareentwickler für Produktions- und Organisationstools, Konverter & Clientlösungen mit Python, C# (WinForms, <mark>WPF</mark>)'},
#     {'jobTitle': 'Softwareentwickler',
#      'periodStart': '2004-09-01T00:00:00.000Z',
#      'periodEnd': '2014-04-30T23:59:59.000Z',
#      'company': 'IAB Communications GmbH',
#      'industryCode': '002',
#      'notes': 'Softwareentwickler für Produktions- und Organisationstools, Konverter & Clientlösungen mit Python, C# (WinForms, <mark>WPF</mark>)'},
#     {'jobTitle': 'Softwareentwickler',
#      'periodStart': '2013-04-01T00:00:00.000Z',
#      'periodEnd': '2013-12-31T23:59:59.000Z',
#      'company': 'ILSS Print&Mail GmbH',
#      'notes': 'Softwareentwickler für Produktions- und Organisationstools, Konverter & Clientlösungen mit Python, C# (WinForms, <mark>WPF</mark>)'}],
#    'education': [{'school': 'mention Software GmbH in Kooperation mit der Deutschen Angestellten Akademie',
#      'periodStart': '2001-09-01T00:00:00.000Z',
#      'periodEnd': '2004-08-31T23:59:59.000Z',
#      'study': 'Informatik',
#      'notes': 'Java, C++, SQL, PHP, HTML'}],
#    'gender': 'm',
#    'hasEmail': False,
#    'hasPhone': False,
#    'hasFax': False,
#    'changeProbability': 45,
#    'mobility': 15,
#    'monthsInJob': 23,
#    'monthsWorking': 206,
#    '_hideInSearch': False,
#    'lastScraped': '2021-10-10T02:23:10.816Z',
#    'lastUpdated': '2021-10-14T18:38:58.243Z',
#    'isFreelancer': False,
#    'isConsultant': False,
#    'isRecruiter': False,
#    'isEntrepreneur': False,
#    'isStudent': False,
#    'isScientist': False,
#    'ml5': {'similarProfiles': {'encoding': ['pos0cluster22',
#       'pos1cluster7',
#       'pos2cluster22',
#       'pos3cluster28',
#       'pos4cluster30',
#       'pos5cluster1',
#       'pos6cluster4',
#       'pos7cluster23',
#       'pos8cluster4',
#       'pos9cluster7',
#       'pos10cluster12',
#       'pos11cluster10',
#       'pos12cluster12',
#       'pos13cluster1',
#       'pos14cluster16',
#       'pos15cluster4',
#       'pos16cluster12',
#       'pos17cluster24',
#       'pos18cluster1',
#       'pos19cluster7']},
#     'profileQuality': 7},
#    '_id': 'aHR0cHM6Ly93d3cueGluZy5jb20vcHJvZmlsZS9NYXRoaWFzX011ZWxsZXIyMDA',
#    'relevance': 73},
#   {'_class': 'xing',
#    'profileURL': 'https://www.xing.com/profile/Graham_Hunter3',
#    'uid': '5389c6a4dca6eecd38ee4d91',
#    'handle': 'graham_hunter3',
#    'imageURL': 'https://profile-images.xing.com/images/0443e82492b727cf81f73b1a9e1d4d02-1/graham-hunter.256x256.jpg',
#    'fullName': 'Graham Hunter',
#    'name': 'Graham Hunter',
#    'firstName': 'Graham',
#    'lastName': 'Hunter',
#    'geoPoint': {'lat': 52.52000659999999, 'lon': 13.404954},
#    'address': {'countryCode': 'de',
#     'country': 'Deutschland',
#     'state': '6.0',
#     'city': 'Berlin'},
#    'location': '<mark>Berlin</mark>, Germany',
#    'jobTitle': '<mark>Software</mark> <mark>Developer</mark>',
#    'previousJobTitles': ['<mark>Java</mark> <mark>Software</mark> <mark>Developer</mark>'],
#    'industry': 'Angestellt, Software Developer, ACI Worldwide',
#    'company': 'ACI Worldwide',
#    'previousCompanies': ['S1'],
#    'skills': ['Java', 'Agile', 'ISO8583', 'JSF', 'C++', 'Maven', 'Jira'],
#    'languagesString': 'English en Afrikaans af',
#    'languages': [{'name': 'English',
#      'level': 'First language',
#      'code': 'en',
#      'levelCode': 5},
#     {'name': 'Afrikaans', 'level': '-', 'code': 'af'}],
#    'jobs': [{'jobTitle': '<mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2012-07-01T00:00:00.000Z',
#      'company': 'ACI Worldwide',
#      'industryCode': '008',
#      'notes': 'ACI Worldwide is a company specializing in payments software. I worked there as a Java Programmer.'},
#     {'jobTitle': 'Java <mark>Software</mark> <mark>Developer</mark>',
#      'periodStart': '2008-01-01T00:00:00.000Z',
#      'periodEnd': '2012-07-31T23:59:59.000Z',
#      'company': 'S1',
#      'notes': 'S1 specialized in payment processing and financial services software for automated teller machines and retail point of sale applications, primarily for banks, retailers and credit unions. I worked there on their internet banking solution using JSF.'},
#     {'jobTitle': 'Java <mark>Software</mark> <mark>Developer</mark>'}],
#    'education': [{'school': 'University of Cape Town',
#      'periodStart': '2003-01-01T00:00:00.000Z',
#      'periodEnd': '2007-12-31T23:59:59.000Z',
#      'study': 'Computer Science'}],
#    'gender': 'm',
#    'hasEmail': False,
#    'hasPhone': False,
#    'hasFax': False,
#    'changeProbability': 35,
#    'mobility': 15,
#    'monthsInJob': 113,
#    'monthsWorking': 167,
#    '_hideInSearch': False,
#    'lastScraped': '2021-10-16T22:39:49.283Z',
#    'lastUpdated': '2021-10-17T00:39:17.672Z',
#    'isFreelancer': False,
#    'isConsultant': False,
#    'isRecruiter': False,
#    'isEntrepreneur': False,
#    'isStudent': False,
#    'isScientist': False,
#    'ml5': {'similarProfiles': {'encoding': ['pos0cluster22',
#       'pos1cluster7',
#       'pos2cluster22',
#       'pos3cluster26',
#       'pos4cluster30',
#       'pos5cluster17',
#       'pos6cluster20',
#       'pos7cluster23',
#       'pos8cluster4',
#       'pos9cluster7',
#       'pos10cluster2',
#       'pos11cluster0',
#       'pos12cluster13',
#       'pos13cluster1',
#       'pos14cluster16',
#       'pos15cluster4',
#       'pos16cluster12',
#       'pos17cluster6',
#       'pos18cluster1',
#       'pos19cluster7']},
#     'profileQuality': 5},
#    '_id': 'aHR0cHM6Ly93d3cueGluZy5jb20vcHJvZmlsZS9HcmFoYW1fSHVudGVyMw',
#    'relevance': 73}],
#  'profileInstanceCount': 9990,
#  'location': GeoPoint(lat=52.5198535, long=13.4385964),
#  'semanticExpansion': {'jobs': [{'name': 'software developer',
#     'isChecked': True},
#    {'name': 'senior software developer', 'isChecked': True},
#    {'name': 'junior software developer', 'isChecked': True},
#    {'name': 'software engineer', 'isChecked': True},
#    {'name': 'freelance software developer', 'isChecked': True},
#    {'name': 'software developer - contractor', 'isChecked': True},
#    {'name': 'software architect', 'isChecked': True},
#    {'name': '.net developer', 'isChecked': True},
#    {'name': 'senior software developer/team lead', 'isChecked': True},
#    {'name': 'developer', 'isChecked': True},
#    {'name': 'expert software developer', 'isChecked': True},
#    {'name': 'software developer and team leader', 'isChecked': True},
#    {'name': 'software developer lead', 'isChecked': True},
#    {'name': 'scala software developer', 'isChecked': True},
#    {'name': 'java developer', 'isChecked': True},
#    {'name': 'developer - contract', 'isChecked': True},
#    {'name': 'senior software engineer', 'isChecked': True},
#    {'name': 'java software developer', 'isChecked': True},
#    {'name': 'software consultant and developer', 'isChecked': True},
#    {'name': 'r&d software developer', 'isChecked': True}],
#   'skills': [{'name': 'typescript', 'isChecked': True},
#    {'name': 'angular', 'isChecked': True},
#    {'name': 'object oriented programming (oop)', 'isChecked': True},
#    {'name': 'c#.net', 'isChecked': True},
#    {'name': 'angular 6', 'isChecked': True},
#    {'name': '.net framework', 'isChecked': True},
#    {'name': 'javaee', 'isChecked': True},
#    {'name': 'c# development', 'isChecked': True},
#    {'name': 'react', 'isChecked': True},
#    {'name': 'backend', 'isChecked': True},
#    {'name': 'entity framwork', 'isChecked': True},
#    {'name': 'microsoft .net', 'isChecked': True},
#    {'name': 'wpf', 'isChecked': True},
#    {'name': '.net development', 'isChecked': True},
#    {'name': 'model-view-controller (mvc)', 'isChecked': True},
#    {'name': 'rest api', 'isChecked': True},
#    {'name': 'qt', 'isChecked': True},
#    {'name': 'asp.net core', 'isChecked': True},
#    {'name': 'xamarin.forms', 'isChecked': True},
#    {'name': 'c# softwareentwicklung', 'isChecked': True}]},
#  'history_id': 'asdf'}
